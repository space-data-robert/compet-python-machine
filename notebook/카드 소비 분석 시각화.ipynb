# %%
import warnings
import pandas as pd
import plotly.express as px
import plotly.graph_objects as go
warnings.filterwarnings('ignore')
pd.set_option('display.max_columns', 16)

# %%
data: pd.DataFrame = pd.read_csv(data_nm)

data.insert(2, 'year_month', pd.to_datetime(
    data.date, format='%Y-%m-%d').dt.strftime('%Y-%m')
)
data.year = data.year.astype('category')

print(f'data.shape = {data.shape}')
data.head(2)
# Out:
# data.shape = (3362796, 15)
#   store_id        date year_month  year  month  day      time  hour  minute  \
# 0    Z0000  2016-12-14    2016-12  2016     12   14  18:05:31    18       5
# 1    Z0000  2016-12-14    2016-12  2016     12   14  18:05:54    18       5
#
#       card_id  amount  installments days_of_week  holiyday  weekend
# 0  D297BBA73F       5             1          WED         0        0
# 1  D297BBA73F      -5             1          WED         0        0

# %%
data.describe(include='object').T
# Out:
#                 count  unique         top    freq
# store_id      3362796    1775       Z0000   68773
# date          3362796      24     2018-05  200462
# time          3362796   85924    12:41:45     157
# card_id       3362796  922522  53817035D4     835
# days_of_week  3362796       7         SAT  533093

# %%
data.describe(exclude='object').T
# Out:
#                   count         mean         std       min     25%     50%  \
# year          3362796.0  2017.247984    0.676447    2016.0  2017.0  2017.0
# month         3362796.0     6.327452    3.333864       1.0     4.0     6.0
# day           3362796.0    15.825904    8.786954       1.0     8.0    16.0
# hour          3362796.0    15.351032    5.191531       0.0    12.0    16.0
# minute        3362796.0    29.513739   17.319572       0.0    15.0    30.0
# amount        3362796.0   145.962304  601.730590 -250000.0    32.0    75.0
# installments  3362796.0     1.012331    0.242138       1.0     1.0     1.0
# holiyday      3362796.0     0.044313    0.205789       0.0     0.0     0.0
# weekend       3362796.0     0.295959    0.456473       0.0     0.0     0.0
#
#                  75%       max
# year          2018.0    2018.0
# month            9.0      12.0
# day             23.0      31.0
# hour            19.0      23.0
# minute          45.0      59.0
# ...

# %%
data_tmp = data.groupby(
    ['year_month', 'year']
).amount.size().reset_index()

figure = px.bar(
    data_tmp,
    x='year_month', y='amount', color='year',
    text_auto=True,
    width=800, height=400,
)
figure.update_layout(
    bargap=0.2, 
    margin=dict(t=20, l=20, b=20, r=20),
)
figure.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
